# %%
import pandas as pd
import numpy as np
import ripleyk
import libpysal as ps
import pointpats
import matplotlib.pyplot as plt

# %%
hemocyte_coordinates = pd.read_csv("/Users/sbandya/Desktop/hemocyte_recruitment_image_quantification/results/hemocyte_coordinates.csv", sep="\t",header=0)
abdomen_coordinates = pd.read_csv("/Users/sbandya/Desktop/hemocyte_recruitment_image_quantification/results/abdomen_coordinates.csv", sep="\t",header=0)

# %%
#Add experimental group info to hemocyte detections
image_condition = pd.Series(abdomen_coordinates.condition.values, index=abdomen_coordinates.Image).to_dict()
hemocyte_coordinates['condition'] = hemocyte_coordinates['Image'].map(image_condition)
hemocyte_coordinates[['fly','section','reporter']] = hemocyte_coordinates['Image'].str.split('_',expand=True)

# %%
#Get numpy arrays
lstat_outs = {}

for image in hemocyte_coordinates['Image'].unique():
    print(image)
    coords = np.array(hemocyte_coordinates.loc[hemocyte_coordinates['Image']==image][["centroid_x_zeroscaled","centroid_y_zeroscaled"]])
    try:
        lstat = pointpats.l_test(coords, keep_simulations=False)
        lstat_outs[image] = lstat
    except:
        pass
# Out:
# 75C_6_FITC.tif
# 75C_5_FITC.tif
# 86F_6_FITC.tif
# 75F_1_FITC.tif
# 75E_6_FITC.tif
# 76B_1_FITC.tif
# 76A_6_FITC.tif
# 85H_1_FITC.tif
# 85H_2_FITC.tif
# 73F_6_FITC.tif
# 84G_3_FITC.tif
# 84G_4_FITC.tif
# 75E_1_FITC.tif
# 75D_5_FITC.tif
# 76B_4_FITC.tif
# 76B_5_FITC.tif
# 80C_5_FITC.tif
# 80C_4_FITC.tif
# 84B_2_FITC.tif
# 84B_1_FITC.tif
# 72F_5_FITC.tif
# 84D_2_FITC.tif
# 84D_1_FITC.tif
# 86D_3_FITC.tif
# 86D_4_FITC.tif
# 72C_2_FITC.tif
# 72C_3_FITC.tif
# 75B_4_FITC.tif
# 75B_3_FITC.tif
# 84F_3_FITC.tif
# 84F_2_FITC.tif
# 90D_5_FITC.tif
# 90E_1_FITC.tif
# 86F_1_FITC.tif
# 86F_2_FITC.tif
# 73C_1_FITC.tif
# 72A_5_FITC.tif
# 72A_4_FITC.tif
# 75A_3_FITC.tif
# 75A_2_FITC.tif
# 72D_3_FITC.tif
# 72D_4_FITC.tif
# 73E_3_FITC.tif
# 73E_5_FITC.tif
# 90B_2_FITC.tif
# 86C_2_FITC.tif
# 90B_1_FITC.tif
# 86C_3_FITC.tif
# 85E_1_FITC.tif
# 90C_4_FITC.tif
# 90C_5_FITC.tif
# 72F_1_FITC.tif
# 72F_2_FITC.tif
# 73B_2_FITC.tif
# 73B_1_FITC.tif
# 84E_3_FITC.tif
# 84E_2_FITC.tif
# 90D_4_FITC.tif
# 90D_3_FITC.tif
# 84B_5_FITC.tif
# 84C_1_FITC.tif
# 72C_5_FITC.tif
# 72C_4_FITC.tif
# 73F_3_FITC.tif
# 73F_2_FITC.tif
# 86E_1_FITC.tif
# 86D_5_FITC.tif
# 90F_2_FITC.tif
# 90F_1_FITC.tif
# 72A_2_FITC.tif
# 72A_3_FITC.tif
# 73D_2_FITC.tif
# 73D_1_FITC.tif
# 73E_2_FITC.tif
# 73E_1_FITC.tif
# 75A_4_FITC.tif
# 75A_5_FITC.tif
# 90C_3_FITC.tif
# 90C_2_FITC.tif
# 86C_5_FITC.tif
# 90A_1_FITC.tif
# 86C_4_FITC.tif
# 86B_1_FITC.tif
# 85F_1_FITC.tif
# 85F_2_FITC.tif
# 72B_3_FITC.tif
# 72B_4_FITC.tif
# 72E_1_FITC.tif
# 72D_5_FITC.tif
# 84E_4_FITC.tif
# 84E_5_FITC.tif
# 75F_4_FITC.tif
# 75B_5_FITC.tif
# 75B_6_FITC.tif
# 85G_1_FITC.tif
# 85F_5_FITC.tif
# 75E_2_FITC.tif
# 75E_3_FITC.tif
# 76C_5_FITC.tif
# 84G_2_FITC.tif
# 84G_1_FITC.tif
# 80C_2_FITC.tif
# 73F_1_FITC.tif
# 73E_6_FITC.tif
# 85E_2_FITC.tif
# 85E_3_FITC.tif
# 86C_1_FITC.tif
# 90A_5_FITC.tif
# 86A_3_FITC.tif
# 90D_2_FITC.tif
# 90D_1_FITC.tif
# 72E_5_FITC.tif
# 72E_4_FITC.tif
# 73D_4_FITC.tif
# 73D_3_FITC.tif
# 73A_4_FITC.tif
# 73A_5_FITC.tif
# 84D_5_FITC.tif
# 84E_1_FITC.tif
# 90F_3_FITC.tif
# 84C_4_FITC.tif
# 84C_5_FITC.tif
# 85F_3_FITC.tif
# 85F_4_FITC.tif
# 72C_1_FITC.tif
# 72B_5_FITC.tif
# 90E_3_FITC.tif
# 90E_2_FITC.tif
# 86E_5_FITC.tif
# 86E_4_FITC.tif
# 73C_3_FITC.tif
# 73C_2_FITC.tif
# 72B_1_FITC.tif
# 72B_2_FITC.tif
# 85G_5_FITC.tif
# 85G_4_FITC.tif
# 80G_1_FITC.tif
# 73F_4_FITC.tif
# 73F_5_FITC.tif
# 84G_5_FITC.tif
# 76C_1_FITC.tif
# 76B_6_FITC.tif
# 75D_3_FITC.tif
# 75D_4_FITC.tif
# 75C_3_FITC.tif
# 75C_4_FITC.tif
# 76D_2_FITC.tif
# 76D_1_FITC.tif
# 76A_4_FITC.tif
# 76A_5_FITC.tif
# 75D_2_FITC.tif
# 75D_1_FITC.tif
# 85G_2_FITC.tif
# 85G_3_FITC.tif
# 76C_2_FITC.tif
# 76C_3_FITC.tif
# 75E_5_FITC.tif
# 75E_4_FITC.tif
# 84F_4_FITC.tif
# 84F_5_FITC.tif
# 75C_2_FITC.tif
# 75C_1_FITC.tif
# 85H_3_FITC.tif
# 85H_4_FITC.tif
# 84B_4_FITC.tif
# 84B_3_FITC.tif
# 76A_3_FITC.tif
# 73D_5_FITC.tif
# 73D_6_FITC.tif
# 75B_2_FITC.tif
# 75B_1_FITC.tif
# 90B_5_FITC.tif
# 90C_1_FITC.tif
# 84D_4_FITC.tif
# 84D_3_FITC.tif
# 85E_5_FITC.tif
# 85E_4_FITC.tif
# 86D_1_FITC.tif
# 90A_3_FITC.tif
# 86D_2_FITC.tif
# 90A_2_FITC.tif
# 86A_5_FITC.tif
# 86A_4_FITC.tif
# 73A_3_FITC.tif
# 72E_2_FITC.tif
# 72E_3_FITC.tif
# 84F_1_FITC.tif
# 86F_3_FITC.tif
# 86F_4_FITC.tif
# 75F_2_FITC.tif
# 75F_3_FITC.tif
# 90B_4_FITC.tif
# 90B_3_FITC.tif
# 84C_3_FITC.tif
# 84C_2_FITC.tif
# 72D_1_FITC.tif
# 72D_2_FITC.tif
# 86E_2_FITC.tif
# 86E_3_FITC.tif
# 90E_4_FITC.tif
# 90E_5_FITC.tif
# 72A_1_FITC.tif
# 72F_3_FITC.tif
# 72F_4_FITC.tif
# 73B_4_FITC.tif
# 73B_3_FITC.tif
# 73C_4_FITC.tif
# 73C_5_FITC.tif

# %%
fig, ax = plt.subplots(1,2, figsize=(15,5))
for image in lstat_outs.keys():
    if image_condition[image] == "Fed":
        ax[0].plot(lstat_outs[image].support, lstat_outs[image].statistic, color='dodgerblue')
    else:
        ax[1].plot(lstat_outs[image].support, lstat_outs[image].statistic, color='darkorange')
plt.xlabel('Distance')
plt.ylabel('L Function')
plt.show()

# %%
from sklearn.neighbors import KDTree
import numpy as np
fed_x = hemocyte_coordinates.loc[hemocyte_coordinates['condition']=="Fed"]['centroid_x_zeroscaled']
fed_y = hemocyte_coordinates.loc[hemocyte_coordinates['condition']=="Fed"]['centroid_y_zeroscaled']

starved_x = hemocyte_coordinates.loc[hemocyte_coordinates['condition']=="Starved"]['centroid_x_zeroscaled']
starved_y = hemocyte_coordinates.loc[hemocyte_coordinates['condition']=="Starved"]['centroid_y_zeroscaled']

fed_coords = np.array([fed_x,fed_y])
starved_coords = np.array([starved_x,starved_y])
#X = np.array([[-1, -1], [-2, -1], [-3, -2], [1, 1], [2, 1], [3, 2]])
kdt = KDTree(fed_coords, metric='euclidean')

# %%
# Out:
# [[0.]]
